# %%
import pandas as pd
import afqinsight.nn.tf_models as nn
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from afqinsight.datasets import AFQDataset
from afqinsight.nn.tf_models import cnn_lenet, mlp4, cnn_vgg, lstm1v0, lstm1, lstm2, blstm1, blstm2, lstm_fcn, cnn_resnet
from sklearn.impute import SimpleImputer
import os.path
# Harmonization
from sklearn.model_selection import train_test_split
from neurocombat_sklearn import CombatModel
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error

import pickle
from tools import load_data, model_fit

# %%
X, y, site = load_data()
# Out:
# 2022-07-13 08:31:40.078008: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-13 08:31:40.085237: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-13 08:31:40.085682: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-13 08:31:40.087125: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-13 08:31:40.087577: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-13 08:31:40.087973: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-13 08:31:40.088322: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-13 08:31:40.733518: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-13 08:31:40.733810: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-13 08:31:40.734057: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-13 08:31:40.734234: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6927 MB memory:  -> device: 0, name: Tesla M60, pci bus id: 0000:00:1e.0, compute capability: 5.2

# %%
from sklearn.utils import shuffle, resample

# %%
from sklearn.metrics import r2_score, median_absolute_error

# %%
model_dict = {
#   "cnn_lenet": {"model": cnn_lenet, "lr": 0.001}, 
  # "mlp4": {"model": mlp4, "lr": 0.001},
  # "cnn_vgg": {"model": cnn_vgg, "lr": 0.001},
  # "lstm1v0": {"model": lstm1v0, "lr": 0.01},
  # "lstm1": {"model": lstm1, "lr": 0.01},
  # "lstm2": {"model": lstm2, "lr": 0.01},
  # "blstm1": {"model": blstm1, "lr": 0.01},
  # "blstm2": {"model": blstm1, "lr": 0.01},
  # "lstm_fcn": {"model": lstm_fcn, "lr": 0.01},
  "cnn_resnet": {"model": cnn_resnet, "lr": 0.01}
             }

# %%
n_runs = 10

# %%
# Generated once with this code and then hard-coded:
# seeds = np.array([np.abs(np.floor(np.random.randn()*1000)) for ii in range(n_runs)], dtype=int)

seeds = np.array([484, 645, 714, 244, 215, 1502, 1334, 1576, 469, 1795])

# %%
def fit_and_eval(model, X, y, random_state, batch_size=128, n_epochs=1000, augment=None, train_size=None):
    model_func = model_dict[model]["model"]
    lr = model_dict[model]["lr"]
    X_train, X_test, y_train, y_test, site_train, site_test = train_test_split(X, y, site, test_size=0.2, random_state=random_state)
    imputer = SimpleImputer(strategy="median")
    # If train_size is set, select train_size subjects to be the training data:
    if train_size is not None:
        X_train, y_train, site_train = resample(X_train, y_train, site_train, replace=False, n_samples=train_size, random_state=random_state)
    
    # Impute train and test separately:
    X_train = np.concatenate([imputer.fit_transform(X_train[..., ii])[:, :, None] for ii in range(X_train.shape[-1])], -1)
    X_test = np.concatenate([imputer.fit_transform(X_test[..., ii])[:, :, None] for ii in range(X_test.shape[-1])], -1)
    # Combat
    X_train = np.concatenate([CombatModel().fit_transform(X_train[..., ii], site_train[:, None], None, None)[:, :, None] for ii in range(X_train.shape[-1])], -1)
    X_test = np.concatenate([CombatModel().fit_transform(X_test[..., ii], site_test[:, None], None, None)[:, :, None] for ii in range(X_test.shape[-1])], -1)
    
    trained = model_fit(model_func, X_train, y_train, lr, 
                        batch_size=batch_size, n_epochs=n_epochs)
    metric = []
    value = []
    
    y_pred = trained.predict(X_test)
    metric.append("mae")
    value.append(mean_absolute_error(y_test, y_pred))
    metric.append("mad")
    value.append(median_absolute_error(y_test, y_pred))
    metric.append("r2")
    value.append(r2_score(y_test, y_pred))
    
    result = {'Model': [model] * len(metric),
              'Metric': metric,
              'Value': value}
    
    return pd.DataFrame(result), pd.DataFrame(dict(y_pred=y_pred.squeeze(), y_test=y_test))

# %%
dfs_eval = []
dfs_pred = []

# %%
for model in model_dict:
    print("##################################################")
    print("model: ", model)
    for ii in range(n_runs): 
        print("run: ", ii)
        this_eval, this_pred = fit_and_eval(
            model, 
            X, 
            y, 
            random_state=seeds[ii],
            train_size=None)
        this_eval["run"] = ii
        this_pred["run"] = ii
        dfs_eval.append(this_eval)
        dfs_pred.append(this_pred)
        # Save evaluation metrics
        one_df = pd.concat(dfs_eval)
        one_df.to_csv("resnet_1_eval.csv")
        # Save predictions and test values:
        one_df = pd.concat(dfs_pred)
        one_df.to_csv("resnet_1_pred.csv")
# Out:
# ##################################################
# model:  cnn_resnet
# run:  0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100, 72)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 100, 64)      36928       input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 100, 64)      256         conv1d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 100, 64)      0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 100, 64)      20544       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100, 64)      256         conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 100, 64)      0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 100, 64)      12352       activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 100, 64)      4672        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 100, 64)      256         conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 100, 64)      256         conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 100, 64)      0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 100, 64)      0           batch_normalization_3[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 100, 64)      0           add[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 100, 128)     65664       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 100, 128)     512         conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 100, 128)     0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 100, 128)     82048       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 100, 128)     512         conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 100, 128)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 100, 128)     49280       activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 100, 128)     8320        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 100, 128)     512         conv1d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 100, 128)     512         conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 100, 128)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 100, 128)     0           batch_normalization_7[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 100, 128)     0           add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 100, 128)     131200      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 100, 128)     512         conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 100, 128)     0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 100, 128)     82048       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 100, 128)     512         conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 100, 128)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 100, 128)     49280       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 100, 128)     512         conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 100, 128)     512         activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 100, 128)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 100, 128)     0           batch_normalization_11[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 100, 128)     0           add_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 128)          0           activation_11[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            129         global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 547,585
# Trainable params: 545,025
# Non-trainable params: 2,560
# __________________________________________________________________________________________________
# Epoch 1/1000
# 2022-07-13 08:31:49.665870: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-07-13 08:31:50.661188: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8101
# 2022-07-13 08:31:50.949769: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-07-13 08:31:50.950245: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-07-13 08:31:50.950289: W tensorflow/stream_executor/gpu/asm_compiler.cc:77] Couldn't get ptxas version string: Internal: Couldn't invoke ptxas --version
# 2022-07-13 08:31:50.951114: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-07-13 08:31:50.951229: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 10/10 [==============================] - 9s 309ms/step - loss: 41.1892 - mean_squared_error: 41.1892 - rmse: 6.4179 - mean_absolute_error: 5.0230 - val_loss: 264853408.0000 - val_mean_squared_error: 264853408.0000 - val_rmse: 16274.3174 - val_mean_absolute_error: 16239.0879
# Epoch 2/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 10.0476 - mean_squared_error: 10.0476 - rmse: 3.1698 - mean_absolute_error: 2.5934 - val_loss: 702977.2500 - val_mean_squared_error: 702977.2500 - val_rmse: 838.4374 - val_mean_absolute_error: 793.7208
# Epoch 3/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 6.6314 - mean_squared_error: 6.6314 - rmse: 2.5752 - mean_absolute_error: 1.9513 - val_loss: 16406.4531 - val_mean_squared_error: 16406.4531 - val_rmse: 128.0877 - val_mean_absolute_error: 124.8312
# Epoch 4/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 5.6862 - mean_squared_error: 5.6862 - rmse: 2.3846 - mean_absolute_error: 1.8432 - val_loss: 4168.4414 - val_mean_squared_error: 4168.4414 - val_rmse: 64.5635 - val_mean_absolute_error: 62.3105
# Epoch 5/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 5.0039 - mean_squared_error: 5.0039 - rmse: 2.2369 - mean_absolute_error: 1.7338 - val_loss: 2551.3083 - val_mean_squared_error: 2551.3083 - val_rmse: 50.5105 - val_mean_absolute_error: 49.7115
# Epoch 6/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 4.4990 - mean_squared_error: 4.4990 - rmse: 2.1211 - mean_absolute_error: 1.6546 - val_loss: 1073.2954 - val_mean_squared_error: 1073.2954 - val_rmse: 32.7612 - val_mean_absolute_error: 32.3505
# Epoch 7/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 4.1764 - mean_squared_error: 4.1764 - rmse: 2.0436 - mean_absolute_error: 1.5754 - val_loss: 601.1194 - val_mean_squared_error: 601.1194 - val_rmse: 24.5177 - val_mean_absolute_error: 24.1203
# Epoch 8/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 3.8138 - mean_squared_error: 3.8138 - rmse: 1.9529 - mean_absolute_error: 1.5027 - val_loss: 327.5091 - val_mean_squared_error: 327.5091 - val_rmse: 18.0972 - val_mean_absolute_error: 17.5913
# Epoch 9/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 3.5222 - mean_squared_error: 3.5222 - rmse: 1.8768 - mean_absolute_error: 1.4390 - val_loss: 219.5392 - val_mean_squared_error: 219.5392 - val_rmse: 14.8169 - val_mean_absolute_error: 14.1685
# Epoch 10/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 3.2132 - mean_squared_error: 3.2132 - rmse: 1.7925 - mean_absolute_error: 1.3830 - val_loss: 155.7663 - val_mean_squared_error: 155.7663 - val_rmse: 12.4806 - val_mean_absolute_error: 11.7056
# Epoch 11/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 3.0787 - mean_squared_error: 3.0787 - rmse: 1.7546 - mean_absolute_error: 1.3499 - val_loss: 100.3643 - val_mean_squared_error: 100.3643 - val_rmse: 10.0182 - val_mean_absolute_error: 9.0952
# Epoch 12/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.8956 - mean_squared_error: 2.8956 - rmse: 1.7016 - mean_absolute_error: 1.3167 - val_loss: 78.4823 - val_mean_squared_error: 78.4823 - val_rmse: 8.8590 - val_mean_absolute_error: 7.8071
# Epoch 13/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 2.7225 - mean_squared_error: 2.7225 - rmse: 1.6500 - mean_absolute_error: 1.2808 - val_loss: 104.0069 - val_mean_squared_error: 104.0069 - val_rmse: 10.1984 - val_mean_absolute_error: 9.2785
# Epoch 14/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.8229 - mean_squared_error: 2.8229 - rmse: 1.6802 - mean_absolute_error: 1.3023 - val_loss: 61.5099 - val_mean_squared_error: 61.5099 - val_rmse: 7.8428 - val_mean_absolute_error: 6.6299
# Epoch 15/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.6458 - mean_squared_error: 2.6458 - rmse: 1.6266 - mean_absolute_error: 1.2730 - val_loss: 17.4424 - val_mean_squared_error: 17.4424 - val_rmse: 4.1764 - val_mean_absolute_error: 3.1303
# Epoch 16/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.5597 - mean_squared_error: 2.5597 - rmse: 1.5999 - mean_absolute_error: 1.2503 - val_loss: 20.1366 - val_mean_squared_error: 20.1366 - val_rmse: 4.4874 - val_mean_absolute_error: 3.8239
# Epoch 17/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.3384 - mean_squared_error: 2.3384 - rmse: 1.5292 - mean_absolute_error: 1.2041 - val_loss: 50.0675 - val_mean_squared_error: 50.0675 - val_rmse: 7.0758 - val_mean_absolute_error: 5.8033
# Epoch 18/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.3169 - mean_squared_error: 2.3169 - rmse: 1.5221 - mean_absolute_error: 1.1817 - val_loss: 24.1614 - val_mean_squared_error: 24.1614 - val_rmse: 4.9154 - val_mean_absolute_error: 3.8768
# Epoch 19/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.5301 - mean_squared_error: 2.5301 - rmse: 1.5906 - mean_absolute_error: 1.2405 - val_loss: 25.0904 - val_mean_squared_error: 25.0904 - val_rmse: 5.0090 - val_mean_absolute_error: 4.2009
# Epoch 20/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.3618 - mean_squared_error: 2.3618 - rmse: 1.5368 - mean_absolute_error: 1.2178 - val_loss: 90.9600 - val_mean_squared_error: 90.9600 - val_rmse: 9.5373 - val_mean_absolute_error: 8.4566
# Epoch 21/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.3423 - mean_squared_error: 2.3423 - rmse: 1.5305 - mean_absolute_error: 1.1973 - val_loss: 27.5640 - val_mean_squared_error: 27.5640 - val_rmse: 5.2501 - val_mean_absolute_error: 4.1274
# Epoch 22/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 2.3819 - mean_squared_error: 2.3819 - rmse: 1.5433 - mean_absolute_error: 1.2178 - val_loss: 59.4372 - val_mean_squared_error: 59.4372 - val_rmse: 7.7096 - val_mean_absolute_error: 6.4442
# Epoch 23/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 2.2571 - mean_squared_error: 2.2571 - rmse: 1.5024 - mean_absolute_error: 1.1820 - val_loss: 39.0839 - val_mean_squared_error: 39.0839 - val_rmse: 6.2517 - val_mean_absolute_error: 4.9774
# Epoch 24/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.2798 - mean_squared_error: 2.2798 - rmse: 1.5099 - mean_absolute_error: 1.1812 - val_loss: 45.9803 - val_mean_squared_error: 45.9803 - val_rmse: 6.7809 - val_mean_absolute_error: 5.6727
# Epoch 25/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 2.5535 - mean_squared_error: 2.5535 - rmse: 1.5980 - mean_absolute_error: 1.2340 - val_loss: 49.4053 - val_mean_squared_error: 49.4053 - val_rmse: 7.0289 - val_mean_absolute_error: 5.8000
# Epoch 26/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.1427 - mean_squared_error: 2.1427 - rmse: 1.4638 - mean_absolute_error: 1.1448 - val_loss: 44.4342 - val_mean_squared_error: 44.4342 - val_rmse: 6.6659 - val_mean_absolute_error: 6.0428
# Epoch 27/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 1.8368 - mean_squared_error: 1.8368 - rmse: 1.3553 - mean_absolute_error: 1.0583 - val_loss: 79.9562 - val_mean_squared_error: 79.9562 - val_rmse: 8.9418 - val_mean_absolute_error: 8.1281
# Epoch 28/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.0159 - mean_squared_error: 2.0159 - rmse: 1.4198 - mean_absolute_error: 1.1023 - val_loss: 36.9718 - val_mean_squared_error: 36.9718 - val_rmse: 6.0804 - val_mean_absolute_error: 5.3167
# Epoch 29/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 1.8931 - mean_squared_error: 1.8931 - rmse: 1.3759 - mean_absolute_error: 1.0695 - val_loss: 20.2322 - val_mean_squared_error: 20.2322 - val_rmse: 4.4980 - val_mean_absolute_error: 3.8131
# Epoch 30/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.2310 - mean_squared_error: 2.2310 - rmse: 1.4937 - mean_absolute_error: 1.1760 - val_loss: 14.5387 - val_mean_squared_error: 14.5387 - val_rmse: 3.8130 - val_mean_absolute_error: 3.1217
# Epoch 31/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.6810 - mean_squared_error: 2.6810 - rmse: 1.6374 - mean_absolute_error: 1.2807 - val_loss: 423.0491 - val_mean_squared_error: 423.0491 - val_rmse: 20.5682 - val_mean_absolute_error: 19.8998
# Epoch 32/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.6457 - mean_squared_error: 2.6457 - rmse: 1.6266 - mean_absolute_error: 1.2575 - val_loss: 32.7536 - val_mean_squared_error: 32.7536 - val_rmse: 5.7231 - val_mean_absolute_error: 4.5096
# Epoch 33/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 2.1956 - mean_squared_error: 2.1956 - rmse: 1.4818 - mean_absolute_error: 1.1483 - val_loss: 57.5813 - val_mean_squared_error: 57.5813 - val_rmse: 7.5882 - val_mean_absolute_error: 6.6408
# Epoch 34/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 2.0352 - mean_squared_error: 2.0352 - rmse: 1.4266 - mean_absolute_error: 1.1093 - val_loss: 15.0948 - val_mean_squared_error: 15.0948 - val_rmse: 3.8852 - val_mean_absolute_error: 3.1775
# Epoch 35/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 2.0121 - mean_squared_error: 2.0121 - rmse: 1.4185 - mean_absolute_error: 1.1039 - val_loss: 43.4893 - val_mean_squared_error: 43.4893 - val_rmse: 6.5946 - val_mean_absolute_error: 5.7343
# Epoch 36/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 2.1161 - mean_squared_error: 2.1161 - rmse: 1.4547 - mean_absolute_error: 1.1212 - val_loss: 10.4914 - val_mean_squared_error: 10.4914 - val_rmse: 3.2390 - val_mean_absolute_error: 2.5574
# Epoch 37/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 1.5937 - mean_squared_error: 1.5937 - rmse: 1.2624 - mean_absolute_error: 0.9913 - val_loss: 40.5138 - val_mean_squared_error: 40.5138 - val_rmse: 6.3650 - val_mean_absolute_error: 5.4477
# Epoch 38/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 1.2432 - mean_squared_error: 1.2432 - rmse: 1.1150 - mean_absolute_error: 0.8764 - val_loss: 36.4290 - val_mean_squared_error: 36.4290 - val_rmse: 6.0356 - val_mean_absolute_error: 5.2045
# Epoch 39/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 1.3617 - mean_squared_error: 1.3617 - rmse: 1.1669 - mean_absolute_error: 0.9075 - val_loss: 35.2052 - val_mean_squared_error: 35.2052 - val_rmse: 5.9334 - val_mean_absolute_error: 4.9911
# Epoch 40/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 1.4553 - mean_squared_error: 1.4553 - rmse: 1.2064 - mean_absolute_error: 0.9476 - val_loss: 29.0249 - val_mean_squared_error: 29.0249 - val_rmse: 5.3875 - val_mean_absolute_error: 4.5699
# Epoch 41/1000
# 10/10 [==============================] - 1s 62ms/step - loss: 1.3294 - mean_squared_error: 1.3294 - rmse: 1.1530 - mean_absolute_error: 0.8962 - val_loss: 45.2360 - val_mean_squared_error: 45.2360 - val_rmse: 6.7258 - val_mean_absolute_error: 5.8537
# Epoch 42/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 1.4810 - mean_squared_error: 1.4810 - rmse: 1.2169 - mean_absolute_error: 0.9592 - val_loss: 12.2971 - val_mean_squared_error: 12.2971 - val_rmse: 3.5067 - val_mean_absolute_error: 2.7155
# Epoch 43/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 1.3031 - mean_squared_error: 1.3031 - rmse: 1.1415 - mean_absolute_error: 0.8990 - val_loss: 30.7194 - val_mean_squared_error: 30.7194 - val_rmse: 5.5425 - val_mean_absolute_error: 4.8854
# Epoch 44/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 1.0693 - mean_squared_error: 1.0693 - rmse: 1.0341 - mean_absolute_error: 0.8029 - val_loss: 140.2068 - val_mean_squared_error: 140.2068 - val_rmse: 11.8409 - val_mean_absolute_error: 11.1295
# Epoch 45/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.9335 - mean_squared_error: 0.9335 - rmse: 0.9662 - mean_absolute_error: 0.7515 - val_loss: 81.7262 - val_mean_squared_error: 81.7262 - val_rmse: 9.0403 - val_mean_absolute_error: 8.3068
# Epoch 46/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.9240 - mean_squared_error: 0.9240 - rmse: 0.9612 - mean_absolute_error: 0.7519 - val_loss: 34.2461 - val_mean_squared_error: 34.2461 - val_rmse: 5.8520 - val_mean_absolute_error: 5.1446
# Epoch 47/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.9733 - mean_squared_error: 0.9733 - rmse: 0.9866 - mean_absolute_error: 0.7666 - val_loss: 20.2816 - val_mean_squared_error: 20.2816 - val_rmse: 4.5035 - val_mean_absolute_error: 3.8606
# Epoch 48/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.8406 - mean_squared_error: 0.8406 - rmse: 0.9168 - mean_absolute_error: 0.7047 - val_loss: 8.2726 - val_mean_squared_error: 8.2726 - val_rmse: 2.8762 - val_mean_absolute_error: 2.2148
# Epoch 49/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.7679 - mean_squared_error: 0.7679 - rmse: 0.8763 - mean_absolute_error: 0.6823 - val_loss: 8.7999 - val_mean_squared_error: 8.7999 - val_rmse: 2.9665 - val_mean_absolute_error: 2.3979
# Epoch 50/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.9461 - mean_squared_error: 0.9461 - rmse: 0.9727 - mean_absolute_error: 0.7577 - val_loss: 13.3244 - val_mean_squared_error: 13.3244 - val_rmse: 3.6503 - val_mean_absolute_error: 2.7970
# Epoch 51/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.9889 - mean_squared_error: 0.9889 - rmse: 0.9944 - mean_absolute_error: 0.7871 - val_loss: 15.3942 - val_mean_squared_error: 15.3942 - val_rmse: 3.9235 - val_mean_absolute_error: 3.0120
# Epoch 52/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.9631 - mean_squared_error: 0.9631 - rmse: 0.9814 - mean_absolute_error: 0.7599 - val_loss: 46.4307 - val_mean_squared_error: 46.4307 - val_rmse: 6.8140 - val_mean_absolute_error: 6.1667
# Epoch 53/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 1.0367 - mean_squared_error: 1.0367 - rmse: 1.0182 - mean_absolute_error: 0.7938 - val_loss: 18.1874 - val_mean_squared_error: 18.1874 - val_rmse: 4.2647 - val_mean_absolute_error: 3.5229
# Epoch 54/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 1.0800 - mean_squared_error: 1.0800 - rmse: 1.0392 - mean_absolute_error: 0.8134 - val_loss: 10.3852 - val_mean_squared_error: 10.3852 - val_rmse: 3.2226 - val_mean_absolute_error: 2.6611
# Epoch 55/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 1.0569 - mean_squared_error: 1.0569 - rmse: 1.0281 - mean_absolute_error: 0.7946 - val_loss: 82.1736 - val_mean_squared_error: 82.1736 - val_rmse: 9.0650 - val_mean_absolute_error: 8.4321
# Epoch 56/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.9219 - mean_squared_error: 0.9219 - rmse: 0.9602 - mean_absolute_error: 0.7528 - val_loss: 6.4455 - val_mean_squared_error: 6.4455 - val_rmse: 2.5388 - val_mean_absolute_error: 2.0105
# Epoch 57/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.7296 - mean_squared_error: 0.7296 - rmse: 0.8542 - mean_absolute_error: 0.6591 - val_loss: 11.4637 - val_mean_squared_error: 11.4637 - val_rmse: 3.3858 - val_mean_absolute_error: 2.5955
# Epoch 58/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.6391 - mean_squared_error: 0.6391 - rmse: 0.7995 - mean_absolute_error: 0.6239 - val_loss: 16.3941 - val_mean_squared_error: 16.3941 - val_rmse: 4.0490 - val_mean_absolute_error: 3.1224
# Epoch 59/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.6035 - mean_squared_error: 0.6035 - rmse: 0.7768 - mean_absolute_error: 0.6084 - val_loss: 12.6776 - val_mean_squared_error: 12.6776 - val_rmse: 3.5606 - val_mean_absolute_error: 2.9310
# Epoch 60/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.7070 - mean_squared_error: 0.7070 - rmse: 0.8408 - mean_absolute_error: 0.6518 - val_loss: 36.2895 - val_mean_squared_error: 36.2895 - val_rmse: 6.0241 - val_mean_absolute_error: 5.3816
# Epoch 61/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.6320 - mean_squared_error: 0.6320 - rmse: 0.7950 - mean_absolute_error: 0.6170 - val_loss: 30.7456 - val_mean_squared_error: 30.7456 - val_rmse: 5.5449 - val_mean_absolute_error: 4.7367
# Epoch 62/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.7151 - mean_squared_error: 0.7151 - rmse: 0.8456 - mean_absolute_error: 0.6599 - val_loss: 9.0917 - val_mean_squared_error: 9.0917 - val_rmse: 3.0152 - val_mean_absolute_error: 2.3635
# Epoch 63/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.7542 - mean_squared_error: 0.7542 - rmse: 0.8684 - mean_absolute_error: 0.6699 - val_loss: 26.1292 - val_mean_squared_error: 26.1292 - val_rmse: 5.1117 - val_mean_absolute_error: 4.4131
# Epoch 64/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.6420 - mean_squared_error: 0.6420 - rmse: 0.8012 - mean_absolute_error: 0.6359 - val_loss: 12.4846 - val_mean_squared_error: 12.4846 - val_rmse: 3.5334 - val_mean_absolute_error: 2.7342
# Epoch 65/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.5812 - mean_squared_error: 0.5812 - rmse: 0.7624 - mean_absolute_error: 0.6183 - val_loss: 11.5470 - val_mean_squared_error: 11.5470 - val_rmse: 3.3981 - val_mean_absolute_error: 2.5546
# Epoch 66/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.5824 - mean_squared_error: 0.5824 - rmse: 0.7631 - mean_absolute_error: 0.5906 - val_loss: 38.8379 - val_mean_squared_error: 38.8379 - val_rmse: 6.2320 - val_mean_absolute_error: 5.5919
# Epoch 67/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.6735 - mean_squared_error: 0.6735 - rmse: 0.8206 - mean_absolute_error: 0.6476 - val_loss: 11.5809 - val_mean_squared_error: 11.5809 - val_rmse: 3.4031 - val_mean_absolute_error: 2.8267
# Epoch 68/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.5744 - mean_squared_error: 0.5744 - rmse: 0.7579 - mean_absolute_error: 0.5976 - val_loss: 16.8108 - val_mean_squared_error: 16.8108 - val_rmse: 4.1001 - val_mean_absolute_error: 3.4009
# Epoch 69/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.4704 - mean_squared_error: 0.4704 - rmse: 0.6858 - mean_absolute_error: 0.5439 - val_loss: 6.0878 - val_mean_squared_error: 6.0878 - val_rmse: 2.4673 - val_mean_absolute_error: 1.9374
# Epoch 70/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.4923 - mean_squared_error: 0.4923 - rmse: 0.7017 - mean_absolute_error: 0.5475 - val_loss: 10.4768 - val_mean_squared_error: 10.4768 - val_rmse: 3.2368 - val_mean_absolute_error: 2.5382
# Epoch 71/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.4794 - mean_squared_error: 0.4794 - rmse: 0.6924 - mean_absolute_error: 0.5459 - val_loss: 31.9057 - val_mean_squared_error: 31.9057 - val_rmse: 5.6485 - val_mean_absolute_error: 4.8921
# Epoch 72/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.4766 - mean_squared_error: 0.4766 - rmse: 0.6904 - mean_absolute_error: 0.5408 - val_loss: 5.9508 - val_mean_squared_error: 5.9508 - val_rmse: 2.4394 - val_mean_absolute_error: 1.9343
# Epoch 73/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.4712 - mean_squared_error: 0.4712 - rmse: 0.6864 - mean_absolute_error: 0.5312 - val_loss: 6.7855 - val_mean_squared_error: 6.7855 - val_rmse: 2.6049 - val_mean_absolute_error: 2.0087
# Epoch 74/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.4076 - mean_squared_error: 0.4076 - rmse: 0.6385 - mean_absolute_error: 0.4990 - val_loss: 9.8970 - val_mean_squared_error: 9.8970 - val_rmse: 3.1459 - val_mean_absolute_error: 2.5591
# Epoch 75/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.4112 - mean_squared_error: 0.4112 - rmse: 0.6413 - mean_absolute_error: 0.5003 - val_loss: 11.5404 - val_mean_squared_error: 11.5404 - val_rmse: 3.3971 - val_mean_absolute_error: 2.7686
# Epoch 76/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3266 - mean_squared_error: 0.3266 - rmse: 0.5715 - mean_absolute_error: 0.4551 - val_loss: 6.4851 - val_mean_squared_error: 6.4851 - val_rmse: 2.5466 - val_mean_absolute_error: 2.0848
# Epoch 77/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.3109 - mean_squared_error: 0.3109 - rmse: 0.5576 - mean_absolute_error: 0.4422 - val_loss: 7.5987 - val_mean_squared_error: 7.5987 - val_rmse: 2.7566 - val_mean_absolute_error: 2.2288
# Epoch 78/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3166 - mean_squared_error: 0.3166 - rmse: 0.5627 - mean_absolute_error: 0.4418 - val_loss: 16.9700 - val_mean_squared_error: 16.9700 - val_rmse: 4.1195 - val_mean_absolute_error: 3.4219
# Epoch 79/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3272 - mean_squared_error: 0.3272 - rmse: 0.5720 - mean_absolute_error: 0.4480 - val_loss: 9.1585 - val_mean_squared_error: 9.1585 - val_rmse: 3.0263 - val_mean_absolute_error: 2.3814
# Epoch 80/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3141 - mean_squared_error: 0.3141 - rmse: 0.5605 - mean_absolute_error: 0.4274 - val_loss: 19.7474 - val_mean_squared_error: 19.7474 - val_rmse: 4.4438 - val_mean_absolute_error: 3.8141
# Epoch 81/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.4117 - mean_squared_error: 0.4117 - rmse: 0.6416 - mean_absolute_error: 0.5025 - val_loss: 6.5599 - val_mean_squared_error: 6.5599 - val_rmse: 2.5612 - val_mean_absolute_error: 2.0421
# Epoch 82/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.3810 - mean_squared_error: 0.3810 - rmse: 0.6172 - mean_absolute_error: 0.4843 - val_loss: 6.7759 - val_mean_squared_error: 6.7759 - val_rmse: 2.6031 - val_mean_absolute_error: 2.1001
# Epoch 83/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.4219 - mean_squared_error: 0.4219 - rmse: 0.6495 - mean_absolute_error: 0.5036 - val_loss: 7.5447 - val_mean_squared_error: 7.5447 - val_rmse: 2.7468 - val_mean_absolute_error: 2.2507
# Epoch 84/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3055 - mean_squared_error: 0.3055 - rmse: 0.5527 - mean_absolute_error: 0.4191 - val_loss: 8.3518 - val_mean_squared_error: 8.3518 - val_rmse: 2.8899 - val_mean_absolute_error: 2.3147
# Epoch 85/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2882 - mean_squared_error: 0.2882 - rmse: 0.5368 - mean_absolute_error: 0.4193 - val_loss: 8.4253 - val_mean_squared_error: 8.4253 - val_rmse: 2.9026 - val_mean_absolute_error: 2.2704
# Epoch 86/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2392 - mean_squared_error: 0.2392 - rmse: 0.4890 - mean_absolute_error: 0.3759 - val_loss: 6.3861 - val_mean_squared_error: 6.3861 - val_rmse: 2.5271 - val_mean_absolute_error: 2.0284
# Epoch 87/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.2620 - mean_squared_error: 0.2620 - rmse: 0.5118 - mean_absolute_error: 0.3945 - val_loss: 26.5814 - val_mean_squared_error: 26.5814 - val_rmse: 5.1557 - val_mean_absolute_error: 4.5273
# Epoch 88/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2305 - mean_squared_error: 0.2305 - rmse: 0.4801 - mean_absolute_error: 0.3801 - val_loss: 10.7513 - val_mean_squared_error: 10.7513 - val_rmse: 3.2789 - val_mean_absolute_error: 2.7592
# Epoch 89/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.2773 - mean_squared_error: 0.2773 - rmse: 0.5266 - mean_absolute_error: 0.4086 - val_loss: 9.4384 - val_mean_squared_error: 9.4384 - val_rmse: 3.0722 - val_mean_absolute_error: 2.4926
# Epoch 90/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.3996 - mean_squared_error: 0.3996 - rmse: 0.6322 - mean_absolute_error: 0.5031 - val_loss: 8.3227 - val_mean_squared_error: 8.3227 - val_rmse: 2.8849 - val_mean_absolute_error: 2.3667
# Epoch 91/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.4049 - mean_squared_error: 0.4049 - rmse: 0.6363 - mean_absolute_error: 0.5078 - val_loss: 5.9722 - val_mean_squared_error: 5.9722 - val_rmse: 2.4438 - val_mean_absolute_error: 1.9550
# Epoch 92/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.4767 - mean_squared_error: 0.4767 - rmse: 0.6905 - mean_absolute_error: 0.5404 - val_loss: 10.0794 - val_mean_squared_error: 10.0794 - val_rmse: 3.1748 - val_mean_absolute_error: 2.6028
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# Epoch 93/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.2911 - mean_squared_error: 0.2911 - rmse: 0.5396 - mean_absolute_error: 0.4018 - val_loss: 8.7341 - val_mean_squared_error: 8.7341 - val_rmse: 2.9553 - val_mean_absolute_error: 2.4547
# Epoch 94/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.1843 - mean_squared_error: 0.1843 - rmse: 0.4293 - mean_absolute_error: 0.3255 - val_loss: 10.3018 - val_mean_squared_error: 10.3018 - val_rmse: 3.2096 - val_mean_absolute_error: 2.6546
# Epoch 95/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.1129 - mean_squared_error: 0.1129 - rmse: 0.3360 - mean_absolute_error: 0.2637 - val_loss: 5.7089 - val_mean_squared_error: 5.7089 - val_rmse: 2.3893 - val_mean_absolute_error: 1.9202
# Epoch 96/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0621 - mean_squared_error: 0.0621 - rmse: 0.2492 - mean_absolute_error: 0.1932 - val_loss: 5.3019 - val_mean_squared_error: 5.3019 - val_rmse: 2.3026 - val_mean_absolute_error: 1.7949
# Epoch 97/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0476 - mean_squared_error: 0.0476 - rmse: 0.2183 - mean_absolute_error: 0.1671 - val_loss: 5.9465 - val_mean_squared_error: 5.9465 - val_rmse: 2.4385 - val_mean_absolute_error: 1.9407
# Epoch 98/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0393 - mean_squared_error: 0.0393 - rmse: 0.1981 - mean_absolute_error: 0.1525 - val_loss: 5.2898 - val_mean_squared_error: 5.2898 - val_rmse: 2.3000 - val_mean_absolute_error: 1.7990
# Epoch 99/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0338 - mean_squared_error: 0.0338 - rmse: 0.1839 - mean_absolute_error: 0.1408 - val_loss: 5.1905 - val_mean_squared_error: 5.1905 - val_rmse: 2.2783 - val_mean_absolute_error: 1.7849
# Epoch 100/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0289 - mean_squared_error: 0.0289 - rmse: 0.1701 - mean_absolute_error: 0.1276 - val_loss: 5.3394 - val_mean_squared_error: 5.3394 - val_rmse: 2.3107 - val_mean_absolute_error: 1.8166
# Epoch 101/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0265 - mean_squared_error: 0.0265 - rmse: 0.1629 - mean_absolute_error: 0.1233 - val_loss: 5.1569 - val_mean_squared_error: 5.1569 - val_rmse: 2.2709 - val_mean_absolute_error: 1.7711
# Epoch 102/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0246 - mean_squared_error: 0.0246 - rmse: 0.1570 - mean_absolute_error: 0.1185 - val_loss: 5.1676 - val_mean_squared_error: 5.1676 - val_rmse: 2.2732 - val_mean_absolute_error: 1.7773
# Epoch 103/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - rmse: 0.1493 - mean_absolute_error: 0.1124 - val_loss: 5.2126 - val_mean_squared_error: 5.2126 - val_rmse: 2.2831 - val_mean_absolute_error: 1.7857
# Epoch 104/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0210 - mean_squared_error: 0.0210 - rmse: 0.1448 - mean_absolute_error: 0.1086 - val_loss: 5.1751 - val_mean_squared_error: 5.1751 - val_rmse: 2.2749 - val_mean_absolute_error: 1.7772
# Epoch 105/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0199 - mean_squared_error: 0.0199 - rmse: 0.1411 - mean_absolute_error: 0.1060 - val_loss: 5.1371 - val_mean_squared_error: 5.1371 - val_rmse: 2.2665 - val_mean_absolute_error: 1.7659
# Epoch 106/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0187 - mean_squared_error: 0.0187 - rmse: 0.1366 - mean_absolute_error: 0.1030 - val_loss: 5.1587 - val_mean_squared_error: 5.1587 - val_rmse: 2.2713 - val_mean_absolute_error: 1.7708
# Epoch 107/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - rmse: 0.1320 - mean_absolute_error: 0.0991 - val_loss: 5.1617 - val_mean_squared_error: 5.1617 - val_rmse: 2.2719 - val_mean_absolute_error: 1.7708
# Epoch 108/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - rmse: 0.1284 - mean_absolute_error: 0.0965 - val_loss: 5.1341 - val_mean_squared_error: 5.1341 - val_rmse: 2.2659 - val_mean_absolute_error: 1.7617
# Epoch 109/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - rmse: 0.1257 - mean_absolute_error: 0.0947 - val_loss: 5.1354 - val_mean_squared_error: 5.1354 - val_rmse: 2.2661 - val_mean_absolute_error: 1.7613
# Epoch 110/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - rmse: 0.1216 - mean_absolute_error: 0.0916 - val_loss: 5.1391 - val_mean_squared_error: 5.1391 - val_rmse: 2.2670 - val_mean_absolute_error: 1.7611
# Epoch 111/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - rmse: 0.1178 - mean_absolute_error: 0.0887 - val_loss: 5.1416 - val_mean_squared_error: 5.1416 - val_rmse: 2.2675 - val_mean_absolute_error: 1.7609
# Epoch 112/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - rmse: 0.1151 - mean_absolute_error: 0.0868 - val_loss: 5.1365 - val_mean_squared_error: 5.1365 - val_rmse: 2.2664 - val_mean_absolute_error: 1.7592
# Epoch 113/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - rmse: 0.1123 - mean_absolute_error: 0.0847 - val_loss: 5.1315 - val_mean_squared_error: 5.1315 - val_rmse: 2.2653 - val_mean_absolute_error: 1.7582
# Epoch 114/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - rmse: 0.1089 - mean_absolute_error: 0.0822 - val_loss: 5.1295 - val_mean_squared_error: 5.1295 - val_rmse: 2.2649 - val_mean_absolute_error: 1.7570
# Epoch 115/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - rmse: 0.1057 - mean_absolute_error: 0.0798 - val_loss: 5.1283 - val_mean_squared_error: 5.1283 - val_rmse: 2.2646 - val_mean_absolute_error: 1.7561
# Epoch 116/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - rmse: 0.1031 - mean_absolute_error: 0.0778 - val_loss: 5.1245 - val_mean_squared_error: 5.1245 - val_rmse: 2.2637 - val_mean_absolute_error: 1.7552
# Epoch 117/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0101 - mean_squared_error: 0.0101 - rmse: 0.1006 - mean_absolute_error: 0.0759 - val_loss: 5.1238 - val_mean_squared_error: 5.1238 - val_rmse: 2.2636 - val_mean_absolute_error: 1.7547
# Epoch 118/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - rmse: 0.0978 - mean_absolute_error: 0.0738 - val_loss: 5.1224 - val_mean_squared_error: 5.1224 - val_rmse: 2.2633 - val_mean_absolute_error: 1.7537
# Epoch 119/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - rmse: 0.0948 - mean_absolute_error: 0.0717 - val_loss: 5.1204 - val_mean_squared_error: 5.1204 - val_rmse: 2.2628 - val_mean_absolute_error: 1.7530
# Epoch 120/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - rmse: 0.0922 - mean_absolute_error: 0.0697 - val_loss: 5.1189 - val_mean_squared_error: 5.1189 - val_rmse: 2.2625 - val_mean_absolute_error: 1.7524
# Epoch 121/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - rmse: 0.0900 - mean_absolute_error: 0.0680 - val_loss: 5.1194 - val_mean_squared_error: 5.1194 - val_rmse: 2.2626 - val_mean_absolute_error: 1.7523
# Epoch 122/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - rmse: 0.0876 - mean_absolute_error: 0.0662 - val_loss: 5.1199 - val_mean_squared_error: 5.1199 - val_rmse: 2.2627 - val_mean_absolute_error: 1.7522
# Epoch 123/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - rmse: 0.0850 - mean_absolute_error: 0.0644 - val_loss: 5.1195 - val_mean_squared_error: 5.1195 - val_rmse: 2.2626 - val_mean_absolute_error: 1.7520
# Epoch 124/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - rmse: 0.0824 - mean_absolute_error: 0.0625 - val_loss: 5.1189 - val_mean_squared_error: 5.1189 - val_rmse: 2.2625 - val_mean_absolute_error: 1.7518
# Epoch 125/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - rmse: 0.0801 - mean_absolute_error: 0.0607 - val_loss: 5.1191 - val_mean_squared_error: 5.1191 - val_rmse: 2.2625 - val_mean_absolute_error: 1.7515
# Epoch 126/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - rmse: 0.0782 - mean_absolute_error: 0.0591 - val_loss: 5.1197 - val_mean_squared_error: 5.1197 - val_rmse: 2.2627 - val_mean_absolute_error: 1.7508
# Epoch 127/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - rmse: 0.0760 - mean_absolute_error: 0.0575 - val_loss: 5.1205 - val_mean_squared_error: 5.1205 - val_rmse: 2.2629 - val_mean_absolute_error: 1.7505
# Epoch 128/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - rmse: 0.0736 - mean_absolute_error: 0.0559 - val_loss: 5.1204 - val_mean_squared_error: 5.1204 - val_rmse: 2.2628 - val_mean_absolute_error: 1.7503
# Epoch 129/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - rmse: 0.0712 - mean_absolute_error: 0.0541 - val_loss: 5.1198 - val_mean_squared_error: 5.1198 - val_rmse: 2.2627 - val_mean_absolute_error: 1.7505
# Epoch 130/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - rmse: 0.0692 - mean_absolute_error: 0.0524 - val_loss: 5.1203 - val_mean_squared_error: 5.1203 - val_rmse: 2.2628 - val_mean_absolute_error: 1.7507
# Epoch 131/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - rmse: 0.0675 - mean_absolute_error: 0.0509 - val_loss: 5.1215 - val_mean_squared_error: 5.1215 - val_rmse: 2.2631 - val_mean_absolute_error: 1.7502
# Epoch 132/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - rmse: 0.0656 - mean_absolute_error: 0.0495 - val_loss: 5.1222 - val_mean_squared_error: 5.1222 - val_rmse: 2.2632 - val_mean_absolute_error: 1.7495
# Epoch 133/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - rmse: 0.0635 - mean_absolute_error: 0.0482 - val_loss: 5.1217 - val_mean_squared_error: 5.1217 - val_rmse: 2.2631 - val_mean_absolute_error: 1.7492
# Epoch 134/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - rmse: 0.0613 - mean_absolute_error: 0.0467 - val_loss: 5.1190 - val_mean_squared_error: 5.1190 - val_rmse: 2.2625 - val_mean_absolute_error: 1.7491
# Epoch 135/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - rmse: 0.0593 - mean_absolute_error: 0.0450 - val_loss: 5.1178 - val_mean_squared_error: 5.1178 - val_rmse: 2.2623 - val_mean_absolute_error: 1.7496
# Epoch 136/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - rmse: 0.0577 - mean_absolute_error: 0.0435 - val_loss: 5.1172 - val_mean_squared_error: 5.1172 - val_rmse: 2.2621 - val_mean_absolute_error: 1.7493
# Epoch 137/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - rmse: 0.0563 - mean_absolute_error: 0.0422 - val_loss: 5.1193 - val_mean_squared_error: 5.1193 - val_rmse: 2.2626 - val_mean_absolute_error: 1.7490
# Epoch 138/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - rmse: 0.0547 - mean_absolute_error: 0.0410 - val_loss: 5.1209 - val_mean_squared_error: 5.1209 - val_rmse: 2.2629 - val_mean_absolute_error: 1.7483
# Epoch 139/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - rmse: 0.0529 - mean_absolute_error: 0.0402 - val_loss: 5.1182 - val_mean_squared_error: 5.1182 - val_rmse: 2.2624 - val_mean_absolute_error: 1.7472
# Epoch 140/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - rmse: 0.0509 - mean_absolute_error: 0.0389 - val_loss: 5.1109 - val_mean_squared_error: 5.1109 - val_rmse: 2.2607 - val_mean_absolute_error: 1.7466
# Epoch 141/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - rmse: 0.0490 - mean_absolute_error: 0.0374 - val_loss: 5.1110 - val_mean_squared_error: 5.1110 - val_rmse: 2.2607 - val_mean_absolute_error: 1.7467
# Epoch 142/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - rmse: 0.0478 - mean_absolute_error: 0.0358 - val_loss: 5.1141 - val_mean_squared_error: 5.1141 - val_rmse: 2.2614 - val_mean_absolute_error: 1.7473
# Epoch 143/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - rmse: 0.0470 - mean_absolute_error: 0.0347 - val_loss: 5.1147 - val_mean_squared_error: 5.1147 - val_rmse: 2.2616 - val_mean_absolute_error: 1.7466
# Epoch 144/1000
# ...
# Epoch 193/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 1.7246e-04 - mean_squared_error: 1.7246e-04 - rmse: 0.0131 - mean_absolute_error: 0.0071 - val_loss: 5.5423 - val_mean_squared_error: 5.5423 - val_rmse: 2.3542 - val_mean_absolute_error: 1.8594
# Epoch 194/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 1.7127e-04 - mean_squared_error: 1.7127e-04 - rmse: 0.0131 - mean_absolute_error: 0.0071 - val_loss: 5.5424 - val_mean_squared_error: 5.5424 - val_rmse: 2.3542 - val_mean_absolute_error: 1.8594
# Epoch 195/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 1.7009e-04 - mean_squared_error: 1.7009e-04 - rmse: 0.0130 - mean_absolute_error: 0.0071 - val_loss: 5.5425 - val_mean_squared_error: 5.5425 - val_rmse: 2.3542 - val_mean_absolute_error: 1.8594
# Epoch 196/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 1.6890e-04 - mean_squared_error: 1.6890e-04 - rmse: 0.0130 - mean_absolute_error: 0.0071 - val_loss: 5.5425 - val_mean_squared_error: 5.5425 - val_rmse: 2.3543 - val_mean_absolute_error: 1.8594
# Epoch 197/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 1.6772e-04 - mean_squared_error: 1.6772e-04 - rmse: 0.0130 - mean_absolute_error: 0.0070 - val_loss: 5.5426 - val_mean_squared_error: 5.5426 - val_rmse: 2.3543 - val_mean_absolute_error: 1.8594
# Epoch 198/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 1.6654e-04 - mean_squared_error: 1.6654e-04 - rmse: 0.0129 - mean_absolute_error: 0.0070 - val_loss: 5.5427 - val_mean_squared_error: 5.5427 - val_rmse: 2.3543 - val_mean_absolute_error: 1.8595
# Epoch 199/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 1.6536e-04 - mean_squared_error: 1.6536e-04 - rmse: 0.0129 - mean_absolute_error: 0.0070 - val_loss: 5.5427 - val_mean_squared_error: 5.5427 - val_rmse: 2.3543 - val_mean_absolute_error: 1.8595
#
# Epoch 00199: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# run:  4
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 100, 72)]    0
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 100, 64)      36928       input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 100, 64)      256         conv1d_44[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 100, 64)      0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 100, 64)      20544       activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 100, 64)      256         conv1d_45[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 100, 64)      0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 100, 64)      12352       activation_49[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 100, 64)      4672        input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 100, 64)      256         conv1d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 100, 64)      256         conv1d_47[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 100, 64)      0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 100, 64)      0           batch_normalization_51[0][0]
#                                                                  activation_50[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 100, 64)      0           add_12[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 100, 128)     65664       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 100, 128)     512         conv1d_48[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 100, 128)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 100, 128)     82048       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 100, 128)     512         conv1d_49[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 100, 128)     0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 100, 128)     49280       activation_53[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 100, 128)     8320        activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 100, 128)     512         conv1d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 100, 128)     512         conv1d_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 100, 128)     0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 100, 128)     0           batch_normalization_55[0][0]
#                                                                  activation_54[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 100, 128)     0           add_13[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 100, 128)     131200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 100, 128)     512         conv1d_52[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 100, 128)     0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 100, 128)     82048       activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 100, 128)     512         conv1d_53[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 100, 128)     0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 100, 128)     49280       activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 100, 128)     512         conv1d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 100, 128)     512         activation_55[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 100, 128)     0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 100, 128)     0           batch_normalization_59[0][0]
#                                                                  activation_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 100, 128)     0           add_14[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_4 (Glo (None, 128)          0           activation_59[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            129         global_average_pooling1d_4[0][0]
# ==================================================================================================
# Total params: 547,585
# Trainable params: 545,025
# Non-trainable params: 2,560
# __________________________________________________________________________________________________
# Epoch 1/1000
# 10/10 [==============================] - 4s 123ms/step - loss: 58.7492 - mean_squared_error: 58.7492 - rmse: 7.6648 - mean_absolute_error: 6.2722 - val_loss: 985735424.0000 - val_mean_squared_error: 985735424.0000 - val_rmse: 31396.4219 - val_mean_absolute_error: 31241.1758
# Epoch 2/1000
# 10/10 [==============================] - 1s 63ms/step - loss: 10.5540 - mean_squared_error: 10.5540 - rmse: 3.2487 - mean_absolute_error: 2.5667 - val_loss: 689930880.0000 - val_mean_squared_error: 689930880.0000 - val_rmse: 26266.5332 - val_mean_absolute_error: 26131.4336
# Epoch 3/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 7.2396 - mean_squared_error: 7.2396 - rmse: 2.6906 - mean_absolute_error: 2.0785 - val_loss: 408917.5938 - val_mean_squared_error: 408917.5938 - val_rmse: 639.4667 - val_mean_absolute_error: 635.2115
# Epoch 4/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 6.0889 - mean_squared_error: 6.0889 - rmse: 2.4676 - mean_absolute_error: 1.9236 - val_loss: 4611.6880 - val_mean_squared_error: 4611.6880 - val_rmse: 67.9094 - val_mean_absolute_error: 67.3715
# Epoch 5/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 5.3998 - mean_squared_error: 5.3998 - rmse: 2.3237 - mean_absolute_error: 1.7960 - val_loss: 175.4514 - val_mean_squared_error: 175.4514 - val_rmse: 13.2458 - val_mean_absolute_error: 12.8334
# Epoch 6/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 4.8214 - mean_squared_error: 4.8214 - rmse: 2.1958 - mean_absolute_error: 1.6922 - val_loss: 19.5725 - val_mean_squared_error: 19.5725 - val_rmse: 4.4241 - val_mean_absolute_error: 3.3696
# Epoch 7/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 4.3828 - mean_squared_error: 4.3828 - rmse: 2.0935 - mean_absolute_error: 1.6145 - val_loss: 51.5950 - val_mean_squared_error: 51.5950 - val_rmse: 7.1830 - val_mean_absolute_error: 6.2166
# Epoch 8/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 3.9754 - mean_squared_error: 3.9754 - rmse: 1.9939 - mean_absolute_error: 1.5267 - val_loss: 15.8658 - val_mean_squared_error: 15.8658 - val_rmse: 3.9832 - val_mean_absolute_error: 3.0401
# Epoch 9/1000
# 10/10 [==============================] - 1s 61ms/step - loss: 3.7254 - mean_squared_error: 3.7254 - rmse: 1.9301 - mean_absolute_error: 1.4808 - val_loss: 17.6001 - val_mean_squared_error: 17.6001 - val_rmse: 4.1952 - val_mean_absolute_error: 3.2044
# Epoch 10/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 3.3741 - mean_squared_error: 3.3741 - rmse: 1.8369 - mean_absolute_error: 1.4233 - val_loss: 17.7024 - val_mean_squared_error: 17.7024 - val_rmse: 4.2074 - val_mean_absolute_error: 3.3489
# Epoch 11/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 3.3467 - mean_squared_error: 3.3467 - rmse: 1.8294 - mean_absolute_error: 1.4231 - val_loss: 16.9046 - val_mean_squared_error: 16.9046 - val_rmse: 4.1115 - val_mean_absolute_error: 3.3605
# Epoch 12/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 3.3237 - mean_squared_error: 3.3237 - rmse: 1.8231 - mean_absolute_error: 1.4158 - val_loss: 43.9062 - val_mean_squared_error: 43.9062 - val_rmse: 6.6262 - val_mean_absolute_error: 5.3186
# Epoch 13/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 3.2873 - mean_squared_error: 3.2873 - rmse: 1.8131 - mean_absolute_error: 1.4105 - val_loss: 28.6685 - val_mean_squared_error: 28.6685 - val_rmse: 5.3543 - val_mean_absolute_error: 4.6320
# Epoch 14/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 3.1125 - mean_squared_error: 3.1125 - rmse: 1.7642 - mean_absolute_error: 1.3714 - val_loss: 18.1878 - val_mean_squared_error: 18.1878 - val_rmse: 4.2647 - val_mean_absolute_error: 3.1454
# Epoch 15/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 3.0070 - mean_squared_error: 3.0070 - rmse: 1.7341 - mean_absolute_error: 1.3463 - val_loss: 14.0357 - val_mean_squared_error: 14.0357 - val_rmse: 3.7464 - val_mean_absolute_error: 2.8226
# Epoch 16/1000
# 10/10 [==============================] - 1s 60ms/step - loss: 2.9876 - mean_squared_error: 2.9876 - rmse: 1.7285 - mean_absolute_error: 1.3570 - val_loss: 20.0705 - val_mean_squared_error: 20.0705 - val_rmse: 4.4800 - val_mean_absolute_error: 3.3406
# Epoch 17/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.7021 - mean_squared_error: 2.7021 - rmse: 1.6438 - mean_absolute_error: 1.2891 - val_loss: 19.0513 - val_mean_squared_error: 19.0513 - val_rmse: 4.3648 - val_mean_absolute_error: 3.7192
# Epoch 18/1000
# 10/10 [==============================] - 1s 59ms/step - loss: 2.6271 - mean_squared_error: 2.6271 - rmse: 1.6208 - mean_absolute_error: 1.2726 - val_loss: 80.4791 - val_mean_squared_error: 80.4791 - val_rmse: 8.9710 - val_mean_absolute_error: 8.2265
# Epoch 19/1000
#  6/10 [=================>............] - ETA: 0s - loss: 2.5302 - mean_squared_error: 2.5302 - rmse: 1.5907 - mean_absolute_error: 1.2357

# %%
for model in model_dict:
    print("##################################################")
    print("model: ", model)
    for ii in range(n_runs): 
        print("run: ", ii)
        this_eval, this_pred = fit_and_eval(
            model, 
            X, 
            y, 
            random_state=seeds[ii],
            train_size=1000)
        this_eval["run"] = ii
        this_pred["run"] = ii
        dfs_eval.append(this_eval)
        dfs_pred.append(this_pred)
        # Save evaluation metrics
        one_df = pd.concat(dfs_eval)
        one_df.to_csv("resnet_2_eval.csv")
        # Save predictions and test values:
        one_df = pd.concat(dfs_pred)
        one_df.to_csv("resnet_2_pred.csv")

# %%
for model in model_dict:
    print("##################################################")
    print("model: ", model)
    for ii in range(n_runs): 
        print("run: ", ii)
        this_eval, this_pred = fit_and_eval(
            model, 
            X, 
            y, 
            random_state=seeds[ii],
            train_size=700)
        this_eval["run"] = ii
        this_pred["run"] = ii
        dfs_eval.append(this_eval)
        dfs_pred.append(this_pred)
        # Save evaluation metrics
        one_df = pd.concat(dfs_eval)
        one_df.to_csv("resnet_3_eval.csv")
        # Save predictions and test values:
        one_df = pd.concat(dfs_pred)
        one_df.to_csv("resnet_3_pred.csv")

# %%
for model in model_dict:
    print("##################################################")
    print("model: ", model)
    for ii in range(n_runs): 
        print("run: ", ii)
        this_eval, this_pred = fit_and_eval(
            model, 
            X, 
            y, 
            random_state=seeds[ii],
            train_size=350)
        this_eval["run"] = ii
        this_pred["run"] = ii
        dfs_eval.append(this_eval)
        dfs_pred.append(this_pred)
        # Save evaluation metrics
        one_df = pd.concat(dfs_eval)
        one_df.to_csv("resnet_4_eval.csv")
        # Save predictions and test values:
        one_df = pd.concat(dfs_pred)
        one_df.to_csv("resnet_4_pred.csv")

# %%
for model in model_dict:
    print("##################################################")
    print("model: ", model)
    for ii in range(n_runs): 
        print("run: ", ii)
        this_eval, this_pred = fit_and_eval(
            model, 
            X, 
            y, 
            random_state=seeds[ii],
            train_size=175)
        this_eval["run"] = ii
        this_pred["run"] = ii
        dfs_eval.append(this_eval)
        dfs_pred.append(this_pred)
        # Save evaluation metrics
        one_df = pd.concat(dfs_eval)
        one_df.to_csv("resnet_5_eval.csv")
        # Save predictions and test values:
        one_df = pd.concat(dfs_pred)
        one_df.to_csv("resnet_5_pred.csv")

# %%
for model in model_dict:
    print("##################################################")
    print("model: ", model)
    for ii in range(n_runs): 
        print("run: ", ii)
        this_eval, this_pred = fit_and_eval(
            model, 
            X, 
            y, 
            random_state=seeds[ii],
            train_size=100)
        this_eval["run"] = ii
        this_pred["run"] = ii
        dfs_eval.append(this_eval)
        dfs_pred.append(this_pred)
        # Save evaluation metrics
        one_df = pd.concat(dfs_eval)
        one_df.to_csv("resnet_6_eval.csv")
        # Save predictions and test values:
        one_df = pd.concat(dfs_pred)
        one_df.to_csv("resnet_6_pred.csv")

# %%
# We want to try different training sample sizes: s
# (1453, 1000, 700, 350, 175)
